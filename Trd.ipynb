# %%
# !pip install yfinance
# !pip install ta
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 6.4 MB 6.7 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.4 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.28.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib
import matplotlib.pyplot as plt
import sklearn as sk
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from matplotlib.pyplot import figure
#from ta import add_all_ta_features
#from ta.utils import dropna
#from ta.volatility import BollingerBands

# %%
pr='5d'
        # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,ma


tf='1m'
        # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
N=3000
M=4
P=2500

# %%
#EUR

EURUSD=yf.download('EURUSD=X', interval =tf, period =pr).reset_index()
EURGBP=yf.download('EURGBP=X', interval =tf, period =pr).reset_index()
EURCAD=yf.download('EURCAD=X', interval =tf, period =pr).reset_index()
EURJPY=yf.download('EURJPY=X', interval =tf, period =pr).reset_index()
EURCHF=yf.download('EURCHF=X', interval =tf, period =pr).reset_index()
EURNZD=yf.download('EURNZD=X', interval =tf, period =pr).reset_index()
EURAUD=yf.download('EURAUD=X', interval =tf, period =pr).reset_index()

print(EURUSD.info())


w=yf.download('EURCAD=X', interval =tf, period =pr)


#Date = pd.DataFrame(EURUSD.iloc[-N:,0])
#Date=pd.DataFrame(data=Date.values , columns=['Date'] )


EURUSD = pd.DataFrame(EURUSD.iloc[-N:,M])
EURUSD=pd.DataFrame(data=EURUSD.values , columns=['EURUSD'] )


EURGBP = pd.DataFrame(EURGBP.iloc[-N:,M])
EURGBP=pd.DataFrame(data=EURGBP.values , columns=['EURGBP'] )

EURCAD = pd.DataFrame(EURCAD.iloc[-N:,M])
EURCAD=pd.DataFrame(data=EURCAD.values , columns=['EURCAD'] )


EURNZD = pd.DataFrame(EURNZD.iloc[-N:,M])
EURNZD=pd.DataFrame(data=EURNZD.values , columns=['EURNZD'] )



EURAUD = pd.DataFrame(EURAUD.iloc[-N:,M])
EURAUD=pd.DataFrame(data=EURAUD.values , columns=['EURAUD'] )


EURJPY = pd.DataFrame(EURJPY.iloc[-N:,M])
EURJPY=pd.DataFrame(data=EURJPY.values , columns=['EURJPY'] )

EURCHF = pd.DataFrame(EURCHF.iloc[-N:,M])
EURCHF=pd.DataFrame(data=EURCHF.values , columns=['EURCHF'] )


DATAEUR= pd.concat([EURUSD,EURGBP,EURCAD,EURAUD,EURNZD,EURJPY,EURCHF] , axis=1)
print(EURNZD)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6487 entries, 0 to 6486
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Datetime   6487 non-null   datetime64[ns, Europe/London]
#  1   Open       6487 non-null   float64
#  2   High       6487 non-null   float64
#  3   Low        6487 non-null   float64
#  4   Close      6487 non-null   float64
#  5   Adj Close  6487 non-null   float64
# ...

# %%
#USD

USDEUR=yf.download('USDEUR=X', interval =tf, period =pr).reset_index()
USDGBP=yf.download('USDGBP=X', interval =tf, period =pr).reset_index()
USDCAD=yf.download('USDCAD=X', interval =tf, period =pr).reset_index()
USDCHF=yf.download('USDCHF=X', interval =tf, period =pr).reset_index()
USDJPY=yf.download('USDJPY=X', interval =tf, period =pr).reset_index()
USDAUD=yf.download('USDAUD=X', interval =tf, period =pr).reset_index()
USDNZD=yf.download('NZDUSD=X', interval =tf, period =pr).reset_index()





#Date = pd.DataFrame(EURUSD.iloc[-1000:,0])
#Date=pd.DataFrame(data=Date.values , columns=['Date'] )



USDEUR = pd.DataFrame(USDEUR.iloc[-N:,M])
USDEUR=pd.DataFrame(data=USDEUR.values , columns=['USDEUR'] )


USDGBP = pd.DataFrame(USDGBP.iloc[-N:,M])
USDGBP=pd.DataFrame(data=USDGBP.values , columns=['USDGBP'] )

USDCAD = pd.DataFrame(USDCAD.iloc[-N:,M])
USDCAD=pd.DataFrame(data=USDCAD.values , columns=['USDCAD'] )


USDAUD = pd.DataFrame(USDAUD.iloc[-N:,M])
USDAUD=pd.DataFrame(data=USDAUD.values , columns=['USDAUD'] )


USDNZD = pd.DataFrame(USDNZD.iloc[-N:,M])
USDNZD=pd.DataFrame(data=1/USDNZD.values , columns=['USDNZD'] )


USDJPY = pd.DataFrame(USDJPY.iloc[-N:,M])
USDJPY=pd.DataFrame(data=USDJPY.values , columns=['USDJPY'] )

USDCHF = pd.DataFrame(USDCHF.iloc[-N:,M])
USDCHF=pd.DataFrame(data=USDCHF.values , columns=['USDCHF'] )




DATAUSD= pd.concat([USDEUR,USDGBP,USDCAD,USDAUD,USDNZD,USDJPY,USDCHF] , axis=1)

print(DATAUSD)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#       USDEUR   USDGBP   USDCAD   USDAUD  USDNZD      USDJPY   USDCHF
# 0     0.9704  0.83090  1.29344  1.47094  1.6152  135.973007  0.96449
# 1     0.9705  0.83094  1.29320  1.47130  1.6147  135.988998  0.96443
# 2     0.9708  0.83158  1.29344  1.47070  1.6150  135.990997  0.96453
# 3     0.9709  0.83172  1.29367  1.47102  1.6149  135.988998  0.96478
# 4     0.9706  0.83157  1.29320  1.47105  1.6149  135.973999  0.96476
# ...      ...      ...      ...      ...     ...         ...      ...
# ...

# %%
AUDUSD=yf.download('AUDUSD=X', interval =tf, period =pr).reset_index()
AUDEUR=yf.download('AUDEUR=X', interval =tf, period =pr).reset_index()
AUDCAD=yf.download('AUDCAD=X', interval =tf, period =pr).reset_index()
AUDJPY=yf.download('AUDJPY=X', interval =tf, period =pr).reset_index()
AUDCHF=yf.download('AUDCHF=X', interval =tf, period =pr).reset_index()
AUDGBP=yf.download('AUDGBP=X', interval =tf, period =pr).reset_index()
AUDNZD=yf.download('AUDNZD=X', interval =tf, period =pr).reset_index()





AUDUSD = pd.DataFrame(AUDUSD.iloc[-N:,M])
AUDUSD=pd.DataFrame(data=AUDUSD.values , columns=['AUDUSD'] )

AUDEUR = pd.DataFrame(AUDEUR.iloc[-N:,M])
AUDEUR=pd.DataFrame(data=AUDEUR.values , columns=['AUDEUR'] )

AUDGBP = pd.DataFrame(AUDGBP.iloc[-N:,M])
AUDGBP=pd.DataFrame(data=AUDGBP.values , columns=['AUDGBP'] )

AUDCAD = pd.DataFrame(AUDCAD.iloc[-N:,M])
AUDCAD=pd.DataFrame(data=AUDCAD.values , columns=['AUDCAD'] )


AUDNZD = pd.DataFrame(AUDNZD.iloc[-N:,M])
AUDNZD=pd.DataFrame(data=AUDNZD.values , columns=['AUDNZD'] )


AUDJPY = pd.DataFrame(AUDJPY.iloc[-N:,M])
AUDJPY=pd.DataFrame(data=AUDJPY.values , columns=['AUDJPY'] )

AUDCHF = pd.DataFrame(AUDCHF.iloc[-N:,M])
AUDCHF=pd.DataFrame(data=AUDCHF.values , columns=['AUDCHF'] )




DATAAUD= pd.concat([AUDUSD,AUDEUR,AUDGBP,AUDCAD,AUDNZD,AUDJPY,AUDCHF] , axis=1)

print(DATAAUD)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#         AUDUSD   AUDEUR   AUDGBP   AUDCAD   AUDNZD     AUDJPY   AUDCHF
# 0     0.679837  0.66010  0.56514  0.87877  1.10403  92.400002  0.65587
# 1     0.679671  0.65987  0.56502  0.87894  1.10403  92.416000  0.65599
# 2     0.679948  0.65997  0.56502  0.87900  1.10401  92.415001  0.65595
# 3     0.679800  0.66007  0.56540  0.87909  1.10391  92.421997  0.65582
# 4     0.679787  0.65995  0.56529  0.87898  1.10405  92.403999  0.65590
# ...

# %%
GBPUSD=yf.download('GBPUSD=X', interval =tf, period =pr).reset_index()
GBPCAD=yf.download('GBPCAD=X', interval =tf, period =pr).reset_index()
GBPEUR=yf.download('GBPEUR=X', interval =tf, period =pr).reset_index()
GBPCHF=yf.download('GBPCHF=X', interval =tf, period =pr).reset_index()
GBPJPY=yf.download('GBPJPY=X', interval =tf, period =pr).reset_index()
GBPNZD=yf.download('GBPNZD=X', interval =tf, period =pr).reset_index()
GBPAUD=yf.download('GBPAUD=X', interval =tf, period =pr).reset_index()




GBPUSD = pd.DataFrame(GBPUSD.iloc[-N:,M])
GBPUSD=pd.DataFrame(data=GBPUSD.values , columns=['GBPUSD'] )


GBPEUR = pd.DataFrame(GBPEUR.iloc[-N:,M])
GBPEUR=pd.DataFrame(data=GBPEUR.values , columns=['GBPEUR'] )

GBPCAD = pd.DataFrame(GBPCAD.iloc[-N:,M])
GBPCAD=pd.DataFrame(data=GBPCAD.values , columns=['GBPCAD'] )


GBPAUD = pd.DataFrame(GBPAUD.iloc[-N:,M])
GBPAUD=pd.DataFrame(data=GBPAUD.values , columns=['GBPAUD'] )


GBPNZD = pd.DataFrame(GBPNZD.iloc[-N:,M])
GBPNZD=pd.DataFrame(data=GBPNZD.values , columns=['GBPNZD'] )


GBPJPY = pd.DataFrame(GBPJPY.iloc[-N:,M])
GBPJPY=pd.DataFrame(data=GBPJPY.values , columns=['GBPJPY'] )

GBPCHF = pd.DataFrame(GBPCHF.iloc[-N:,M])
GBPCHF=pd.DataFrame(data=GBPCHF.values , columns=['GBPCHF'] )




DATAGBP= pd.concat([GBPUSD,GBPEUR,GBPCAD,GBPAUD,GBPNZD,GBPJPY,GBPCHF] , axis=1)

print(DATAGBP)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#         GBPUSD   GBPEUR   GBPCAD   GBPAUD   GBPNZD      GBPJPY   GBPCHF
# 0     1.203456  1.16867  1.55515  1.76962  1.95355  163.453003  1.16084
# 1     1.203283  1.16895  1.55465  1.76990  1.95466  163.485001  1.16079
# 2     1.203398  1.16851  1.55494  1.76953  1.95420  163.470993  1.16105
# 3     1.203442  1.16866  1.55486  1.76981  1.95460  163.434006  1.16070
# 4     1.203283  1.16861  1.55509  1.76957  1.95449  163.429993  1.16060
# ...

# %%
NZDUSD=yf.download('NZDUSD=X', interval =tf, period =pr).reset_index()
NZDEUR=yf.download('NZDEUR=X', interval =tf, period =pr).reset_index()
NZDCAD=yf.download('NZDCAD=X', interval =tf, period =pr).reset_index()
NZDJPY=yf.download('NZDJPY=X', interval =tf, period =pr).reset_index()
NZDCHF=yf.download('NZDCHF=X', interval =tf, period =pr).reset_index()
NZDGBP=yf.download('NZDGBP=X', interval =tf, period =pr).reset_index()
NZDAUD=yf.download('NZDAUD=X', interval =tf, period =pr).reset_index()



NZDUSD = pd.DataFrame(NZDUSD.iloc[-N:,M])
NZDUSD=pd.DataFrame(data=NZDUSD.values , columns=['NZDUSD'] )

NZDEUR = pd.DataFrame(NZDEUR.iloc[-N:,M])
NZDEUR=pd.DataFrame(data=AUDEUR.values , columns=['NZDEUR'] )

NZDCAD = pd.DataFrame(NZDCAD.iloc[-N:,M])
NZDCAD=pd.DataFrame(data=NZDCAD.values , columns=['NZDCAD'] )

NZDJPY = pd.DataFrame(NZDJPY.iloc[-N:,M])
NZDJPY=pd.DataFrame(data=NZDJPY.values , columns=['NZDJPY'] )


NZDCHF = pd.DataFrame(NZDCHF.iloc[-N:,M])
NZDCHF=pd.DataFrame(data=NZDCHF.values , columns=['NZDCHF'] )


NZDGBP = pd.DataFrame(NZDGBP.iloc[-N:,M])
NZDGBP=pd.DataFrame(data=NZDGBP.values , columns=['NZDGBP'] )

NZDAUD = pd.DataFrame(NZDAUD.iloc[-N:,M])
NZDAUD=pd.DataFrame(data=NZDAUD.values , columns=['NZDAUD'] )




DATANZD= pd.concat([NZDUSD,NZDEUR,NZDGBP,NZDCAD,NZDAUD,NZDJPY,NZDCHF] , axis=1)

print(DATANZD)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#         NZDUSD   NZDEUR   NZDGBP   NZDCAD   NZDAUD     NZDJPY   NZDCHF
# 0     0.619042  0.66010  0.51144  0.79617  0.90536  83.713997  0.59409
# 1     0.618927  0.65987  0.51149  0.79585  0.90548  83.697998  0.59397
# 2     0.618774  0.65997  0.51156  0.79583  0.90542  83.693001  0.59386
# 3     0.618429  0.66007  0.51139  0.79591  0.90530  83.712997  0.59391
# 4     0.618238  0.65995  0.51144  0.79592  0.90521  83.695000  0.59378
# ...

# %%
CHFUSD=yf.download('USDCHF=X', interval =tf, period =pr).reset_index()
CHFEUR=yf.download('EURCHF=X', interval =tf, period =pr).reset_index()
CHFGBP=yf.download('GBPCHF=X', interval =tf, period =pr).reset_index()
CHFCAD=yf.download('CADCHF=X', interval =tf, period =pr).reset_index()
CHFNZD=yf.download('NZDCHF=X', interval =tf, period =pr).reset_index()
CHFAUD=yf.download('AUDCHF=X', interval =tf, period =pr).reset_index()
CHFJPY=yf.download('CHFJPY=X', interval =tf, period =pr).reset_index()




CHFUSD = pd.DataFrame(CHFUSD.iloc[-N:,M])
CHFUSD=pd.DataFrame(data=1/CHFUSD.values , columns=['CHFUSD'] )

CHFEUR = pd.DataFrame(CHFEUR.iloc[-N:,M])
CHFEUR=pd.DataFrame(data=1/CHFEUR.values , columns=['CHFEUR'] )

CHFGBP = pd.DataFrame(CHFGBP.iloc[-N:,M])
CHFGBP=pd.DataFrame(data=1/CHFGBP.values , columns=['CHFGBP'] )

CHFCAD = pd.DataFrame(CHFCAD.iloc[-N:,M])
CHFCAD=pd.DataFrame(data=1/CHFCAD.values , columns=['CHFCAD'] )


CHFNZD = pd.DataFrame(CHFNZD.iloc[-N:,M])
CHFNZD=pd.DataFrame(data=1/CHFNZD.values , columns=['CHFNZD'] )


CHFAUD = pd.DataFrame(CHFAUD.iloc[-N:,M])
CHFAUD=pd.DataFrame(data=1/CHFAUD.values , columns=['CHFAUD'] )

CHFJPY = pd.DataFrame(CHFJPY.iloc[-N:,M])
CHFJPY=pd.DataFrame(data=CHFJPY.values , columns=['CHFJPY'] )




DATACHF= pd.concat([CHFUSD,CHFEUR,CHFGBP,CHFCAD,CHFAUD,CHFNZD,CHFJPY] , axis=1)

print(DATANZD)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#         NZDUSD   NZDEUR   NZDGBP   NZDCAD   NZDAUD     NZDJPY   NZDCHF
# 0     0.619042  0.66010  0.51144  0.79617  0.90536  83.713997  0.59409
# 1     0.618927  0.65987  0.51149  0.79585  0.90548  83.697998  0.59397
# 2     0.618774  0.65997  0.51156  0.79583  0.90542  83.693001  0.59386
# 3     0.618429  0.66007  0.51139  0.79591  0.90530  83.712997  0.59391
# 4     0.618238  0.65995  0.51144  0.79592  0.90521  83.695000  0.59378
# ...

# %%
JPYUSD=yf.download('USDJPY=X', interval =tf, period =pr).reset_index()
JPYEUR=yf.download('EURJPY=X', interval =tf, period =pr).reset_index()
JPYGBP=yf.download('GBPJPY=X', interval =tf, period =pr).reset_index()
JPYCAD=yf.download('CADJPY=X', interval =tf, period =pr).reset_index()
JPYNZD=yf.download('NZDJPY=X', interval =tf, period =pr).reset_index()
JPYAUD=yf.download('AUDJPY=X', interval =tf, period =pr).reset_index()
JPYCHF=yf.download('JPYCHF=X', interval =tf, period =pr).reset_index()


JPYUSD = pd.DataFrame(JPYUSD.iloc[-N:,M])
JPYUSD=pd.DataFrame(data=1/JPYUSD.values , columns=['JPYUSD'] )

JPYEUR = pd.DataFrame(JPYEUR.iloc[-N:,M])
JPYEUR=pd.DataFrame(data=1/JPYEUR.values , columns=['JPYEUR'] )

JPYGBP = pd.DataFrame(JPYGBP.iloc[-N:,M])
JPYGBP=pd.DataFrame(data=1/JPYGBP.values , columns=['JPYGBP'] )

JPYCAD = pd.DataFrame(JPYCAD.iloc[-N:,M])
JPYCAD=pd.DataFrame(data=1/JPYCAD.values , columns=['JPYCAD'] )


JPYNZD = pd.DataFrame(JPYNZD.iloc[-N:,M])
JPYNZD=pd.DataFrame(data=1/JPYNZD.values , columns=['JPYNZD'] )


JPYAUD = pd.DataFrame(JPYAUD.iloc[-N:,M])
JPYAUD=pd.DataFrame(data=1/JPYAUD.values , columns=['JPYAUD'] )

JPYCHF = pd.DataFrame(JPYCHF.iloc[-N:,M])
JPYCHF=pd.DataFrame(data=JPYCHF.values , columns=['JPYCHF'] )




DATAJPY= pd.concat([JPYUSD,JPYEUR,JPYGBP,JPYCAD,JPYAUD,JPYNZD,JPYCHF] , axis=1)

print(DATAJPY)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#         JPYUSD    JPYEUR    JPYGBP    JPYCAD    JPYAUD    JPYNZD    JPYCHF
# 0     0.007357  0.007148  0.006115  0.009513  0.010824  0.011945  0.007089
# 1     0.007358  0.007146  0.006114  0.009511  0.010822  0.011948  0.007089
# 2     0.007359  0.007145  0.006115  0.009512  0.010821  0.011948  0.007088
# 3     0.007360  0.007147  0.006113  0.009512  0.010824  0.011946  0.007087
# 4     0.007359  0.007147  0.006115  0.009512  0.010823  0.011948  0.007097
# ...

# %%
CADUSD=yf.download('CADUSD=X', interval =tf, period =pr).reset_index()
CADEUR=yf.download('EURCAD=X', interval =tf, period =pr).reset_index()
CADGBP=yf.download('GBPCAD=X', interval =tf, period =pr).reset_index()
CADJPY=yf.download('CADJPY=X', interval =tf, period =pr).reset_index()
CADNZD=yf.download('NZDCAD=X', interval =tf, period =pr).reset_index()
CADAUD=yf.download('AUDCAD=X', interval =tf, period =pr).reset_index()
CADCHF=yf.download('CADCHF=X', interval =tf, period =pr).reset_index()


CADUSD = pd.DataFrame(CADUSD.iloc[-N:,M])
CADUSD=pd.DataFrame(data=CADUSD.values , columns=['CADUSD'] )

CADEUR = pd.DataFrame(CADEUR.iloc[-N:,M])
CADEUR=pd.DataFrame(data=1/CADEUR.values , columns=['CADEUR'] )

CADGBP = pd.DataFrame(CADGBP.iloc[-N:,M])
CADGBP=pd.DataFrame(data=1/CADGBP.values , columns=['CADGBP'] )

CADJPY = pd.DataFrame(CADJPY.iloc[-N:,M])
CADJPY=pd.DataFrame(data=CADJPY.values , columns=['CADJPY'] )

CADNZD = pd.DataFrame(CADNZD.iloc[-N:,M])
CADNZD=pd.DataFrame(data=1/CADNZD.values , columns=['CADNZD'] )

CADAUD = pd.DataFrame(CADAUD.iloc[-N:,M])
CADAUD=pd.DataFrame(data=1/CADAUD.values , columns=['CADAUD'] )

CADCHF = pd.DataFrame(CADCHF.iloc[-N:,M])
CADCHF=pd.DataFrame(data=CADCHF.values , columns=['CADCHF'] )




DATACAD= pd.concat([CADUSD,CADEUR,CADGBP,CADJPY,CADAUD,CADNZD,CADCHF] , axis=1)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
DATAEUR['EUR']=((DATAEUR['EURCAD']+DATAEUR['EURGBP']+DATAEUR['EURNZD']+DATAEUR['EURAUD']+DATAEUR['EURJPY']+DATAEUR['EURCHF']+DATAEUR['EURUSD'])/7)
DATAUSD['USD']=((DATAUSD['USDCAD']+DATAUSD['USDGBP']+DATAUSD['USDNZD']+DATAUSD['USDAUD']+DATAUSD['USDJPY']+DATAUSD['USDCHF']+DATAUSD['USDEUR'])/7)
DATACAD['CAD']=((DATACAD['CADEUR']+DATACAD['CADGBP']+DATACAD['CADNZD']+DATACAD['CADAUD']+DATACAD['CADJPY']+DATACAD['CADCHF']+DATACAD['CADUSD'])/7)
DATAGBP['GBP']=((DATAGBP['GBPUSD']+DATAGBP['GBPEUR']+DATAGBP['GBPCAD']+DATAGBP['GBPAUD']+DATAGBP['GBPNZD']+DATAGBP['GBPCHF']+DATAGBP['GBPJPY'])/7)
DATAAUD['AUD']=((DATAAUD['AUDUSD']+DATAAUD['AUDEUR']+DATAAUD['AUDGBP']+DATAAUD['AUDCAD']+DATAAUD['AUDJPY']+DATAAUD['AUDCHF']+DATAAUD['AUDNZD'])/7)
DATANZD['NZD']=((DATANZD['NZDUSD']+DATANZD['NZDCAD']+DATANZD['NZDGBP']+DATANZD['NZDEUR']+DATANZD['NZDJPY']+DATANZD['NZDCHF']+DATANZD['NZDAUD'])/7)
DATACHF['CHF']=((DATACHF['CHFEUR']+DATACHF['CHFGBP']+DATACHF['CHFNZD']+DATACHF['CHFAUD']+DATACHF['CHFJPY']+DATACHF['CHFUSD']+DATACHF['CHFCAD'])/7)
DATAJPY['JPY']=((DATAJPY['JPYEUR']+DATAJPY['JPYGBP']+DATAJPY['JPYNZD']+DATAJPY['JPYAUD']+DATAJPY['JPYCHF']+DATAJPY['JPYUSD']+DATAJPY['JPYCAD'])/7)


dt= pd.concat([DATAUSD,DATACAD,DATAGBP,DATANZD,DATAAUD,DATACHF,DATAJPY,DATAEUR] , axis=1)
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 64 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   USDEUR  3000 non-null   float64
#  1   USDGBP  3000 non-null   float64
#  2   USDCAD  3000 non-null   float64
#  3   USDAUD  3000 non-null   float64
#  4   USDNZD  3000 non-null   float64
#  5   USDJPY  3000 non-null   float64
#  6   USDCHF  3000 non-null   float64
#  7   USD     3000 non-null   float64
#  8   CADUSD  3000 non-null   float64
#  9   CADEUR  3000 non-null   float64
#  10  CADGBP  3000 non-null   float64
#  11  CADJPY  3000 non-null   float64
#  12  CADAUD  3000 non-null   float64
#  13  CADNZD  3000 non-null   float64
#  14  CADCHF  3000 non-null   float64
#  15  CAD     3000 non-null   float64
#  16  GBPUSD  3000 non-null   float64
#  17  GBPEUR  3000 non-null   float64
#  18  GBPCAD  3000 non-null   float64
#  19  GBPAUD  3000 non-null   float64
# ...

# %%
dt['SUM']= dt['USD']+ dt['CAD']+ dt['EUR']+ dt['NZD']+ dt['AUD']+ dt['GBP']

# %%
dt1=dt.iloc[1:P,:].copy(deep=True)
dt2=dt.iloc[P:,:].copy(deep=True)



sl1=StandardScaler()
sl2=StandardScaler()

dt1.iloc[:,:]=sl1.fit_transform(dt1.iloc[:,:])
dt2.iloc[:,:]=sl2.fit_transform(dt2.iloc[:,:])

df=dt.copy(deep=True)

sld=StandardScaler()

df.iloc[:,:]=sld.fit_transform(df.iloc[:,:])

# %%
do= dt[['CAD','USD','GBP','AUD','EUR','NZD','CHF','JPY']].corr()

cm =do[do>0.5][do<1]
cm.style.background_gradient(cmap='coolwarm')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/style.py:2813: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/style.py:2814: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# ...

# %%
df[['CAD','USD','GBP','AUD','EUR','NZD','CHF']].plot(figsize=(30,10))
#plt.axvline(x = P, color = 'b', label = 'axvline - full height')
plt.axhline(y = 0, color = 'r', linestyle = 'dashed')

# %% [markdown]
# ---
#
#
#
# ---

# %%
df[['CAD','USD','GBP','EUR']].plot(figsize=(30,10))
plt.axvline(x = P, color = 'b', label = 'axvline - full height')
plt.axhline(y = 0, color = 'r', linestyle = 'dashed')

# %%
Q=(df['EUR']-df['USD'])
(df['EUR']-df['USD']).plot(figsize=(30,10))

plt.axhline(y =-((Q).std()), color = 'g', linestyle = 'dashed')    
plt.axhline(y =-2*((Q).std()), color = 'g', linestyle = 'dashed')    
plt.axhline(y =-3*((Q).std()), color = 'g', linestyle = 'dashed')    
plt.axhline(y =-4*((Q).std()), color = 'g', linestyle = 'dashed')    

plt.axhline(y =((Q).std()), color = 'g', linestyle = 'dashed')    
plt.axhline(y =2*((Q).std()), color = 'g', linestyle = 'dashed')    
plt.axhline(y =3*((Q).std()), color = 'g', linestyle = 'dashed')    
plt.axhline(y =4*((Q).std()), color = 'g', linestyle = 'dashed')    


plt.axhline(y = 0, color = 'r', linestyle = 'dashed')    
plt.axvline(x = P, color = 'b', label = 'axvline - full height', linestyle = 'dashed')

# %%
df[['EUR','USD']].plot(figsize=(30,10))
#plt.axvline(x = P, color = 'b', label = 'axvline - full height')
plt.axhline(y = 0, color = 'r', linestyle = 'dashed')    
plt.axvline(x = 1400, color = 'b', label = 'axvline - full height', linestyle = 'dashed')

# %%
do= dt[['CAD','USD','GBP','AUD','EUR','NZD','CHF','JPY']].tail(200).corr()

#plt.figure(figsize=(300, 100))

import matplotlib.pyplot as plt
  

cm =do[do>0.2]
cm.style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_3bc70_row0_col0, #T_3bc70_row1_col1, #T_3bc70_row2_col2, #T_3bc70_row3_col3, #T_3bc70_row4_col4, #T_3bc70_row5_col5, #T_3bc70_row6_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_3bc70_row0_col1 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_3bc70_row0_col2, #T_3bc70_row0_col4, #T_3bc70_row0_col5, #T_3bc70_row0_col6, #T_3bc70_row0_col7, #T_3bc70_row1_col3, #T_3bc70_row1_col7, #T_3bc70_row2_col7, #T_3bc70_row3_col1, #T_3bc70_row3_col7, #T_3bc70_row4_col7, #T_3bc70_row5_col7, #T_3bc70_row6_col0, #T_3bc70_row6_col7, #T_3bc70_row7_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_3bc70_row0_col3 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_3bc70_row1_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_3bc70_row1_col2 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_3bc70_row1_col4 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_3bc70_row1_col5 {
# ...

# %%
import seaborn as sns
  
# checking correlation using heatmap
#Loading dataset
dc =  dt[['CAD','USD','GBP','AUD','EUR','NZD','CHF','JPY']].corr()

cm =dc[dc>0.7][dc<1]

#ploting the heatmap for correlation


fig, ax = plt.subplots(figsize=(20,10))         # Sample figsize in inches
sns.heatmap(cm,  linewidths=.5, ax=ax , cmap='Blues', annot=True ,linecolor='Black')

# %%
do= dt[['CAD','USD','GBP','EUR']].corr()

cm =do[do>0.7][do<1]
fig, ax = plt.subplots(figsize=(18,10))         # Sample figsize in inches
sns.heatmap(cm, cmap='coolwarm', annot=True, linewidths=.5, ax=ax)

# %%
minus=pd.DataFrame()

dc= df[['CAD','USD','GBP','AUD','EUR','NZD','CHF']].copy(deep=True)
lis= []
for i in range(0,len(dc)):

  lis.append(max(dc.iloc[i,:])-min(dc.iloc[i,:]))



minus=pd.DataFrame(lis)
plt.figure(figsize=(30,10))

plt.plot(minus,color='r')

M= minus.mean()
#plt.axhline(y = M, color = 'b', label = 'axvline - full height')
plt.axhline(y = 0, color = 'r', linestyle = 'dashed')    
#plt.plot(dt['USDCHF'].tail(1000))
#plt.axvline(x = P, color = 'b', label = 'axvline - full height')

# %%
dt1[['CAD','USD','GBP','AUD','EUR','NZD','CHF']].tail(400).plot(figsize=(30,10))
#plt.axvline(x = P, color = 'b', label = 'axvline - full height')
plt.axhline(y = 0, color = 'r', linestyle = 'dashed')
